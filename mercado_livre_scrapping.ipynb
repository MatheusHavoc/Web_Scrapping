# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusHavoc/Web_Scrapping/blob/main/mercado_livre_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Importar bibliotecas
from bs4 import BeautifulSoup
from bs4.element import Tag
import requests
from time import sleep
import pandas as pd
import numpy as np
from IPython.display import clear_output

# %%
# Habilitar visualizador de tabelas do Google Colab
from google.colab import data_table

# %%
# Acessar site 
url_base  =  'https://lista.mercadolivre.com.br/'

# - Obtendo produtos do Mercado Livre a partir de uma busca realizada pelo usuário
produto_nome  =  input ( 'Qual produto você deseja? ' ) 
ML_address  =  (url_base + produto_nome) # É interessante que as siglas tenham um complemento pra entender do que se trata
#------------------------------------------------------------------------------------------------------

ML_req = requests.get(ML_address)
soup = BeautifulSoup(ML_req.text, "html.parser") # É interessante manter as convenções adotadas nas próprias bibliotecas. No casso do BeautifulSoup, recomendam usar o nome de variável 'soup' (https://beautiful-soup-4.readthedocs.io/en/latest/#quick-start)
# Out:
# Qual produto você deseja? iPhone

# %%
# Definir todos os CSS Selectors

# Página de resultados
css_product_card = ".ui-search-layout__item.shops__layout-item"
css_product_title = ".ui-search-item__title.shops__item-title"
css_product_details_link = ".ui-search-item__group__element.shops__items-group-details.ui-search-link"
css_product_price = ".price-tag-fraction"

# Página do produto
css_product_attributes_table_row = ".andes-table__row.ui-vpp-striped-specs__row"
css_product_attributes_color_label = ".ui-pdp-variations__label.ui-pdp-color--BLACK"
css_product_attributes_color = ".ui-pdp-variations__selected-label.ui-pdp-color--BLACK"

# %%
# Selecionar todos os cards dos produtos

product_cards = soup.select(css_product_card)

# %%
# Criar uma função que busca o elemento <a href="..." class="ui-search-item__group__element shops__items-group-details ui-search-link"></a> dentro do card do produto e returna uma tupla com valor de title e href

def get_product_basic_info(product_card: Tag) -> str:
  product_details_link_element = product_card.select_one(css_product_details_link)
  product_title = product_details_link_element.get_attribute_list('title')[0]
  product_link = product_details_link_element.get_attribute_list('href')[0]
  product_price = product_card.select_one(css_product_price).text
  return product_title, product_link, product_price

# %%
# Criar uma função que busca todas as linhas de atributos do produto a partir da página do produto, transforma em um dicionário {nome do atributo: valor} e retorna esse dicionário

def get_product_attributes(product_soup: BeautifulSoup) -> dict:
  attributes_table_rows = product_soup.select(css_product_attributes_table_row)
  attributes_dict = {}
  for row in attributes_table_rows:
    attribute_name = row.select_one('th').text
    attribute_value = row.select_one('td').text
    attributes_dict[attribute_name] = attribute_value
  description_attribute_labels = product_soup.select(css_product_attributes_color_label)

  if len(description_attribute_labels): # Alguns atributos ficam ao lado da foto do produto (fora da tabela), verificar se foi encontrado algum e insere no dicionário de atributos
    for description_attribute_label in description_attribute_labels:
      if "Memória interna:" in description_attribute_label.text: attributes_dict['Memória interna'] = description_attribute_label.text.replace("Memória interna:", "")
      if "Cor:" in description_attribute_label.text: attributes_dict['Cor'] = description_attribute_label.text.replace("Cor:", "")

  return attributes_dict

# %%
# Faz um loop na lista de cards de produtos, requisita o link do produto e armazena o título, link e atributos do produto em uma lista

products = []
for idx, product_card in enumerate(product_cards):
  product_title, product_link, product_price = get_product_basic_info(product_card)
  product_attributes = {}
  while len(product_attributes.keys()) <= 2:
    print(f'{idx}/{len(product_cards)} | Tentando buscar atributos do produto: {product_title}') # Colocando uma repetição pois as vezes a página do Mercado Livre não retorna a tabela de atributos, então é preciso tentar novamente.
    product_soup = BeautifulSoup(requests.get(product_link).text, 'html.parser')
    product_attributes = get_product_attributes(product_soup)
  products.append({
      'Título': product_title,
      'Link': product_link,
      'Preço': product_price,
      **product_attributes
  })
clear_output()

# %%
df = pd.DataFrame.from_dict(products)
df['Preço'] = df['Preço'].astype('float')

# %%
df
# Out:
#                                                Título  \
# 0                    Apple iPhone 11 (64 GB) - Branco
# 1             Apple iPhone 11 (256 GB) - (PRODUCT)RED
# 2              Apple iPhone 14 Pro (128 GB) - Dourado
# 3      Apple iPhone 14 Pro Max (1 TB) - Roxo-profundo
# 4              Apple iPhone 13 Pro (128 GB) - Dourado
# 5              Apple iPhone 12 Pro (128 GB) - Grafite
# 6                      Apple iPhone XR 128 GB - Preto
# 7                       iPhone X 64 GB cinza-espacial
# 8          Apple iPhone 12 Pro Max (256 GB) - Grafite
# 9                   Apple iPhone 12 (128 GB) - Branco
# 10                       iPhone 8 Plus 128 GB dourado
# 11                           iPhone 7 32gb - Seminovo
# 12                      iPhone 8 64 GB cinza-espacial
# 13        iPhone 6 Plus 16gb Cinza Espacial Muito Bom
# 14        Apple iPhone SE (2a geração) 128 GB - Preto
# 15                      Apple iPhone XR 64 GB - Preto
# 16                   Apple iPhone XR 256 GB - Amarelo
# 17                    iPhone 7 Plus 128gb Dourado Bom
# 18                 iPhone 8 Plus 64 GB cinza-espacial
# 19  Apple iPhone XS 64gb Original Vitrine Pronta E...
# 20                 Apple iPhone 13 (512 GB) - Estelar
# 21        iPhone 6s 16gb Prateado Bom - Celular Usado
# 22                iPhone 6s Plus 32 GB cinza-espacial
# 23  iPhone 11 64gb Tela De 6,1  Câmera Dupla De 12...
# 24  iPhone X 64gb Vitrine + Brinde 12x Sem Juros P...
# 25                iPhone 12 128gb 6.1'' 5g Azul Apple
# 26  iPhone 8 Vitrine 64gb  Apple Exposição 12x S/ ...
# 27   iPhone XR 64 Gb Preto Original De Vitrine Sem...
# 28  iPhone 8 Plus Gold 64 Gb Vitrine Chave Carrega...
# 29  iPhone 7 128gb Preto Matte Excelente - Trocafo...
# 30  Apple iPhone XS 256 Gb Cinza-espacial  5k 4g -...
# 31              Apple iPhone 11 128 Gb Branco Vitrine
# 32  iPhone 12 128gb 4gb De Ram Tela De 6,1  5g Pre...
# 33   iPhone 8 64 Gb Dourado - Vitrine  Pronta Entr...
# 34          iPhone 8 Plus 64gb Original + Nota Fiscal
# 35  iPhone XR 64 Gb Branco Vitrine Brinde Chave Ca...
# 36                     iPhone 7 256gb Preto Matte Bom
# 49                                             iPhone
#
#                         Modelo             Cor Memória interna Memória RAM  \
# 0                    iPhone 11          Branco           64 GB        4 GB
# 1                    iPhone 11    (Product)Red          256 GB        4 GB
# 2                iPhone 14 Pro         Dourado          128 GB        6 GB
# 3            iPhone 14 Pro Max   Roxo-profundo            1 TB        6 GB
# 4                iPhone 13 Pro         Dourado          128 GB        6 GB
# 5                iPhone 12 Pro         Grafite          128 GB        6 GB
# 6                    iPhone XR           Preto          128 GB        3 GB
# 7                     iPhone X  Cinza-espacial           64 GB        3 GB
# 8            iPhone 12 Pro Max         Grafite          256 GB        6 GB
# 9                    iPhone 12          Branco          128 GB        4 GB
# 10               iPhone 8 Plus         Dourado          128 GB        3 GB
# 11                    iPhone 7            Rosa           32 GB        2 GB
# 12                    iPhone 8  Cinza-espacial           64 GB        2 GB
# 13                      6 Plus  Cinza-espacial           16 GB        1 GB
# 14  iPhone SE (2nd Generation)           Preto          128 GB        3 GB
# 15                   iPhone XR           Preto           64 GB        3 GB
# 16                   iPhone XR         Amarelo          256 GB        3 GB
# 17                      7 Plus         Dourado          128 GB        3 GB
# 18               iPhone 8 Plus  Cinza-espacial           64 GB        3 GB
# 19                   iPhone XS  Cinza-espacial           64 GB        4 GB
# 20                   iPhone 13         Estelar          512 GB        4 GB
# 21                          6s        Prateado           16 GB        2 GB
# 22              iPhone 6s Plus  Cinza-espacial           32 GB        2 GB
# 23                   iPhone 11           Preto           64 GB        4 GB
# 24                    iPhone X  Cinza-espacial           64 GB        3 GB
# 25                   iPhone 12            Azul          128 GB        4 GB
# 26                    iPhone 8            Ouro           64 GB        2 GB
# 27                   iPhone XR           Preto           64 GB        3 GB
# 28               iPhone 8 Plus         Dourado           64 GB        3 GB
# 29                           7     Preto Matte          128 GB        2 GB
# 30                   iPhone XS  Cinza-espacial          256 GB        4 GB
# 31                   iPhone 11          Branco          128 GB        4 GB
# 32                   iPhone 12           Preto          128 GB        4 GB
# 33                    iPhone 8         Dourado           64 GB        2 GB
# 34               iPhone 8 Plus        Prateado           64 GB        3 GB
# 35                   iPhone XR          Branco           64 GB        3 GB
# 36                           7     Preto Matte          256 GB        2 GB
# 37                    iPhone X        Prateado           64 GB        3 GB
# 38                   iPhone XS  Cinza-espacial           64 GB        4 GB
# 39                   iPhone 11           Preto           64 GB        4 GB
# 40                   iPhone 12           Preto           64 GB        4 GB
# 41                    iPhone 8            Ouro           64 GB        2 GB
# 42                    iPhone 7         Dourado           32 GB        2 GB
# 43                    iPhone X  Cinza-espacial           64 GB        3 GB
# 44                   iPhone 11           Preto           64 GB        4 GB
# 45                           8  Cinza-espacial           64 GB        2 GB
# 46                    iPhone X        Prateado           64 GB        3 GB
# 47                   iPhone 11           Preto          128 GB        4 GB
# 48                   MQ6G2BR/A  Cinza-espacial           64 GB        2 GB
# 49                   iPhone 11          Branco           64 GB        4 GB
#
#    Com ranhura para cartão de memória  ... Inclui lápis  \
# 0                                 Não  ...          NaN
# 1                                 Não  ...          NaN
# 2                                 NaN  ...          Não
# 3                                 NaN  ...          Não
# 4                                 Não  ...          NaN
# 5                                 Não  ...          NaN
# 6                                 Não  ...          NaN
# 7                                 NaN  ...          NaN
# 8                                 Não  ...          NaN
# 9                                 Não  ...          NaN
# 10                                Não  ...          NaN
# 11                                Não  ...          NaN
# 12                                Não  ...          NaN
# 13                                NaN  ...          NaN
# 14                                Não  ...          NaN
# 15                                Não  ...          NaN
# 16                                Não  ...          NaN
# 17                                Não  ...          NaN
# 18                                Não  ...          NaN
# 19                                Não  ...          NaN
# 20                                Não  ...          NaN
# 21                                Não  ...          NaN
# 22                                Não  ...          NaN
# 23                                Não  ...          NaN
# 24                                NaN  ...          Não
# 25                                Não  ...          NaN
# 26                                Não  ...          NaN
# 27                                Não  ...          NaN
# 28                                Não  ...          NaN
# 29                                Não  ...          NaN
# 30                                Não  ...          NaN
# 31                                Não  ...          NaN
# 32                                Não  ...          NaN
# 33                                Não  ...          NaN
# 34                                Não  ...          NaN
# 35                                Não  ...          NaN
# 36                                Não  ...          NaN
# 37                                NaN  ...          NaN
# 38                                Não  ...          NaN
# 39                                Não  ...          NaN
# 40                                Não  ...          NaN
# 41                                Não  ...          NaN
# 42                                Não  ...          NaN
# 43                                NaN  ...          NaN
# 44                                Não  ...          NaN
# 45                                Não  ...          NaN
# 46                                NaN  ...          NaN
# 47                                Não  ...          NaN
# 48                                Não  ...          NaN
# 49                                Não  ...          NaN
#
#    Autonomia de conversação Com botão SOS É resistente a quedas  \
# 0                       NaN           NaN                   NaN
# 1                       NaN           NaN                   NaN
# 2                      75 h           Sim                   Sim
# 3                      95 h           Sim                   Sim
# 4                       NaN           NaN                   NaN
# 5                       NaN           NaN                   NaN
# 6                      25 h           NaN                   NaN
# 7                      21 h           NaN                   NaN
# 8                       NaN           NaN                   NaN
# 9                       NaN           NaN                   NaN
# 10                     21 h           NaN                   NaN
# 11                     14 h           NaN                   NaN
# 12                     14 h           NaN                   NaN
# 13                     24 h           NaN                   NaN
# 14                      NaN           NaN                   Não
# 15                     25 h           NaN                   NaN
# 16                     25 h           NaN                   NaN
# 17                     21 h           NaN                   NaN
# 18                     21 h           NaN                   NaN
# 19                     20 h           NaN                   NaN
# 20                      NaN           NaN                   NaN
# 21                     14 h           NaN                   NaN
# 22                     24 h           NaN                   NaN
# 23                      NaN           NaN                   NaN
# 24                     21 h           NaN                   NaN
# 25                      NaN           NaN                   Sim
# 26                     14 h           NaN                   NaN
# 27                     25 h           NaN                   NaN
# 28                     21 h           NaN                   NaN
# 29                     14 h           NaN                   NaN
# 30                     20 h           NaN                   NaN
# 31                      NaN           NaN                   NaN
# 32                      NaN           NaN                   Sim
# 33                     14 h           NaN                   NaN
# 34                     21 h           NaN                   NaN
# 35                     25 h           NaN                   NaN
# 36                     14 h           NaN                   NaN
# 37                     21 h           NaN                   NaN
# 38                     20 h           NaN                   NaN
# 39                      NaN           NaN                   NaN
# 40                      NaN           NaN                   Sim
# 41                     14 h           NaN                   NaN
# 42                     14 h           NaN                   NaN
# 43                     21 h           NaN                   NaN
# 44                      NaN           NaN                   NaN
# 45                     14 h           NaN                   NaN
# 46                     21 h           NaN                   NaN
# 47                      NaN           NaN                   NaN
# 48                     14 h           NaN                   NaN
# 49                      NaN           NaN                   NaN
#
#    Autonomia da batería em standby Homologação Anatel Nº Com IMEI  \
# 0                              NaN                   NaN      NaN
# 1                              NaN                   NaN      NaN
# 2                              NaN                   NaN      NaN
# 3                              NaN                   NaN      NaN
# 4                              NaN                   NaN      NaN
# 5                              NaN                   NaN      NaN
# 6                              NaN                   NaN      NaN
# 7                            240 h                   NaN      NaN
# 8                              NaN                   NaN      NaN
# 9                              NaN                   NaN      NaN
# 10                           240 h                   NaN      NaN
# 11                           240 h           32671601993      Sim
# 12                           240 h                   NaN      NaN
# 13                           384 h                   NaN      Sim
# 14                             NaN                   NaN      NaN
# 15                             NaN                   NaN      NaN
# 16                             NaN                   NaN      NaN
# 17                           384 h                   NaN      Sim
# 18                           240 h                   NaN      NaN
# 19                             NaN           50401801993      Sim
# 20                             NaN                   NaN      NaN
# 21                           240 h                   NaN      Sim
# 22                           384 h                   NaN      NaN
# 23                             NaN                   NaN      Sim
# 24                           240 h                   NaN      Sim
# 25                             NaN                   NaN      Sim
# 26                           240 h           51491701993      Sim
# 27                             NaN                   NaN      Sim
# 28                           240 h           51481701993      Sim
# 29                           240 h                   NaN      Sim
# 30                             NaN           50401801993      Sim
# 31                             NaN                   NaN      Sim
# 32                             NaN                   NaN      Sim
# 33                           240 h           51491701993      Sim
# 34                           240 h                   NaN      Sim
# 35                             NaN           50391801993      Sim
# 36                           240 h                   NaN      Sim
# 37                           240 h                   NaN      Sim
# 38                             NaN           50401801993      Sim
# 39                             NaN                   NaN      Sim
# 40                             NaN                   NaN      Sim
# 41                           240 h                   NaN      Sim
# 42                           240 h                   NaN      Sim
# 43                           240 h                   NaN      Sim
# 44                             NaN                   NaN      Sim
# 45                           240 h                   NaN      Sim
# 46                           240 h                   NaN      Sim
# 47                             NaN                   NaN      Sim
# 48                           240 h                   NaN      Sim
# 49                             NaN                   NaN      Sim
#
#        Operadora Com reconhecimento de mão Resolução da câmera grande-angular
# 0            NaN                       NaN                                NaN
# 1            NaN                       NaN                                NaN
# 2            NaN                       NaN                                NaN
# 3            NaN                       NaN                                NaN
# 4            NaN                       NaN                                NaN
# 5            NaN                       NaN                                NaN
# 6            NaN                       NaN                                NaN
# 7            NaN                       NaN                                NaN
# 8            NaN                       NaN                                NaN
# 9            NaN                       NaN                                NaN
# 10           NaN                       NaN                                NaN
# 11  Desbloqueado                       NaN                                NaN
# 12           NaN                       NaN                                NaN
# 13  Desbloqueado                       NaN                                NaN
# 14           NaN                       Não                                NaN
# 15           NaN                       NaN                                NaN
# 16           NaN                       NaN                                NaN
# 17  Desbloqueado                       NaN                                NaN
# 18           NaN                       NaN                                NaN
# 19  Desbloqueado                       NaN                                NaN
# 20           NaN                       NaN                                NaN
# 21  Desbloqueado                       NaN                                NaN
# 22           NaN                       NaN                                NaN
# 23  Desbloqueado                       NaN                             12 Mpx
# 24  Desbloqueado                       NaN                                NaN
# 25  Desbloqueado                       NaN                                NaN
# 26  Desbloqueado                       NaN                                NaN
# 27  Desbloqueado                       NaN                                NaN
# 28  Desbloqueado                       NaN                                NaN
# 29  Desbloqueado                       NaN                                NaN
# 30  Desbloqueado                       NaN                                NaN
# 31  Desbloqueado                       NaN                                NaN
# 32  Desbloqueado                       NaN                             12 Mpx
# 33  Desbloqueado                       NaN                                NaN
# 34  Desbloqueado                       NaN                                NaN
# 35  Desbloqueado                       NaN                                NaN
# 36  Desbloqueado                       NaN                                NaN
# 37  Desbloqueado                       NaN                                NaN
# 38  Desbloqueado                       NaN                                NaN
# 39  Desbloqueado                       NaN                                NaN
# 40  Desbloqueado                       NaN                             12 Mpx
# 41  Desbloqueado                       NaN                                NaN
# 42  Desbloqueado                       NaN                                NaN
# 43  Desbloqueado                       NaN                                NaN
# 44  Desbloqueado                       NaN                                NaN
# 45  Desbloqueado                       NaN                                NaN
# 46  Desbloqueado                       NaN                                NaN
# 47  Desbloqueado                       NaN                                NaN
# 48  Desbloqueado                       NaN                                NaN
# 49  Desbloqueado                       NaN                                NaN
#
# [50 rows x 94 columns]

# %%
# Apagando titulo df
df = df.drop(['Título'], axis=1) 
# Apagando  colunas com valores nulls 
df = df.dropna(axis=1)  
df = df.reset_index(drop=True)
df.head(5)
# Out:
#                                                 Link   Preço  Marca   Linha  \
# 0  https://www.mercadolivre.com.br/apple-iphone-1...   3.025  Apple  iPhone
# 1  https://www.mercadolivre.com.br/apple-iphone-1...   3.549  Apple  iPhone
# 2  https://www.mercadolivre.com.br/apple-iphone-1...   8.399  Apple  iPhone
# 3  https://www.mercadolivre.com.br/apple-iphone-1...  14.799  Apple  iPhone
# 4  https://www.mercadolivre.com.br/apple-iphone-1...   7.240  Apple  iPhone
#
#               Modelo            Cor Memória interna Memória RAM  \
# 0          iPhone 11         Branco           64 GB        4 GB
# 1          iPhone 11   (Product)Red          256 GB        4 GB
# 2      iPhone 14 Pro        Dourado          128 GB        6 GB
# 3  iPhone 14 Pro Max  Roxo-profundo            1 TB        6 GB
# 4      iPhone 13 Pro        Dourado          128 GB        6 GB
#
#   Nome do sistema operacional Versão original do sistema operacional  ...  \
# 0                         iOS                                     13  ...
# 1                         iOS                                     13  ...
# 2                         iOS                                     16  ...
# 3                         iOS                                     16  ...
# 4                         iOS                                     15  ...
#
#   Tecnologia da tela Pixels por polegada da tela Com tela tátil  \
# 0                IPS                     326 ppi            Sim
# 1                IPS                     326 ppi            Sim
# 2               OLED                     460 ppi            Sim
# 3               OLED                     460 ppi            Sim
# 4               OLED                     460 ppi            Sim
#
#   Tipo de bateria Com bateria removível Com teclado QWERTY físico  \
# 0    Íon de lítio                   Não                       Não
# 1    Íon de lítio                   Não                       Não
# 2    Íon de lítio                   Não                       Não
# 3    Íon de lítio                   Não                       Não
# 4    Íon de lítio                   Não                       Não
#
#   Modelo do processador Com acelerômetro Com sensor de proximidade  \
# 0      Apple A13 Bionic              Sim                       Sim
# 1      Apple A13 Bionic              Sim                       Sim
# 2      Apple A16 Bionic              Sim                       Sim
# 3      Apple A16 Bionic              Sim                       Sim
# 4      Apple A15 Bionic              Sim                       Sim
#
#   Com giroscópio
# 0            Sim
# 1            Sim
# 2            Sim
# 3            Sim
# 4            Sim
#
# [5 rows x 40 columns]

# %%
# Mostrar o produto index 5 como exemplo

df.iloc[5].to_dict()
# Out:
# {'Link': 'https://www.mercadolivre.com.br/apple-iphone-12-pro-128-gb-grafite/p/MLB16163679?pdp_filters=category:MLB1055#searchVariation=MLB16163679&position=6&search_layout=stack&type=product&tracking_id=4a9dece9-e5a5-4ea7-a42d-bdaac0516fd8',
#  'Preço': 6.999,
#  'Marca': 'Apple',
#  'Linha': 'iPhone',
#  'Modelo': 'iPhone 12 Pro',
#  'Cor': 'Grafite',
#  'Memória interna': '128 GB',
#  'Memória RAM': '6 GB',
#  'Nome do sistema operacional': 'iOS',
#  'Versão original do sistema operacional': '14',
#  'Resolução da câmera traseira principal': '12 Mpx',
#  'Resolução de vídeo da câmera traseira': '3840 px x 2160 px',
#  'Resolução da câmera frontal principal': '12 Mpx',
#  'Com câmera': 'Sim',
#  'Quantidade de câmeras traseiras': '3',
#  'Abertura do diafragma da câmera traseira': 'f 1.6/f 2.0/f 2.4',
#  'Quantidade de câmeras frontais': '1',
#  'Resolução de vídeo da câmera frontal': '3840 px x 2160 px',
#  'Altura x Largura x Profundidade': '146.7 mm x 71.5 mm x 7.4 mm',
#  'Rede': '5G',
#  'Com conector USB': 'Não',
#  'Com Wi-Fi': 'Sim',
#  'Com GPS': 'Sim',
#  'Com Bluetooth': 'Sim',
#  'É Dual SIM': 'Não',
#  'Quantidade de ranhuras para cartão SIM': '1',
#  'Tamanhos de cartão SIM compatíveis': 'Nano-SIM',
#  'Com eSIM': 'Sim',
#  'Tamanho da tela': '6.1 "',
#  'Resolução da tela': '1170 px x 2532 px',
#  'Tecnologia da tela': 'OLED',
#  'Pixels por polegada da tela': '460 ppi',
#  'Com tela tátil': 'Sim',
#  'Tipo de bateria': 'Íon de lítio',
#  'Com bateria removível': 'Não',
#  'Com teclado QWERTY físico': 'Não',
#  'Modelo do processador': 'Apple A14 Bionic',
#  'Com acelerômetro': 'Sim',
#  'Com sensor de proximidade': 'Sim',
#  'Com giroscópio': 'Sim'}
